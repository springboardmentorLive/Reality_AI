# %%
from PIL import Image
image_path = "virat kohli.jpeg"
image = Image.open(image_path)
print(f"Successfully opened {image_path}")
# Out:
# Successfully opened virat kohli.jpeg

# %%
rotated_image = image.rotate(90, expand=True)
print("Image rotated by 90 degrees.")
display(rotated_image)
# Out:
# Image rotated by 90 degrees.
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
rotated_image = image.rotate(180, expand=True)
print("Image rotated by 90 degrees.")
display(rotated_image)
# Out:
# Image rotated by 90 degrees.
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
rotated_image = image.rotate(270, expand=True)
print("Image rotated by 90 degrees.")
display(rotated_image)
# Out:
# Image rotated by 90 degrees.
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
grayscale_image = rotated_image.convert('L')
print("Image converted to grayscale.")
display(grayscale_image)
# Out:
# Image converted to grayscale.
# <PIL.Image.Image image mode=L size=225x225>
