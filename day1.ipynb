# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentorLive/Reality_AI/blob/bhaskar/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
left = pd.DataFrame({"key":["K0", "K1", "K2", "K3"],
                     "A":["A0", "A1", "A2", "A3"],
                     "B":["B0", "B1", "B2", "B3"],
})
right = pd.DataFrame({"key":["K0", "K1", "K2", "K3"],
                      "C":["C0", "C1", "C2", "C3"],
                      "D":["D0", "D1", "D2", "D3"],
})
result = pd.merge(left, right, on="key")

result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
import pandas as pd
left = pd.DataFrame(
    {"key1":["K0", "K0", "K1", "K2"],
     "key2":["K0", "K1", "K0", "K1"],
     "A":["A0", "A1", "A2", "A3"],
     "B":["B0", "B1", "B2", "B3"],
    })
right = pd.DataFrame(
    {"key1":["K0", "K1", "K1", "K2"],
     "key2":["K0", "K0", "K0", "K0"],
     "C":["C0", "C1", "C2", "C3"],
     "D":["D0", "D1", "D2", "D3"],
    })
result = pd.merge(left, right, how="left", on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
import pandas as pd
left = pd.DataFrame(
    {"key1":["K0", "K0", "K1", "K2"],
     "key2":["K0", "K1", "K0", "K1"],
     "A":["A0", "A1", "A2", "A3"],
     "B":["B0", "B1", "B2", "B3"],
    })
right = pd.DataFrame(
    {"key1":["K0", "K1", "K1", "K2"],
     "key2":["K0", "K0", "K0", "K0"],
     "C":["C0", "C1", "C2", "C3"],
     "D":["D0", "D1", "D2", "D3"],
    })
result = pd.merge(left, right, how="outer", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %%
import pandas as pd
left = pd.DataFrame(
    {"key1":["K0", "K0", "K1", "K2"],
     "key2":["K0", "K1", "K0", "K1"],
     "A":["A0", "A1", "A2", "A3"],
     "B":["B0", "B1", "B2", "B3"],
    })
right = pd.DataFrame(
    {"key1":["K0", "K1", "K1", "K2"],
     "key2":["K0", "K0", "K0", "K0"],
     "C":["C0", "C1", "C2", "C3"],
     "D":["D0", "D1", "D2", "D3"],
    })
result = pd.merge(left, right, how="right", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
import pandas as pd
left = pd.DataFrame(
    {"key1":["K0", "K0", "K1", "K2"],
     "key2":["K0", "K1", "K0", "K1"],
     "A":["A0", "A1", "A2", "A3"],
     "B":["B0", "B1", "B2", "B3"],
    })
right = pd.DataFrame(
    {"key1":["K0", "K1", "K1", "K2"],
     "key2":["K0", "K0", "K0", "K0"],
     "C":["C0", "C1", "C2", "C3"],
     "D":["D0", "D1", "D2", "D3"],
    })
result = pd.merge(left, right, how="inner", on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
import pandas as pd
data = {'Name':["Bhaskar", "surya", "pavan","lakshmi"],
        'Age':[23,20,21,25],
        'marks':[None, 75,69,85]}
print(data)
# Out:
# {'Name': ['Bhaskar', 'surya', 'pavan', 'lakshmi'], 'Age': [23, 20, 21, 25], 'marks': [None, 75, 69, 85]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  marks
# 0  Bhaskar   23    NaN
# 1    surya   20   75.0
# 2    pavan   21   69.0
# 3  lakshmi   25   85.0

# %%
df.isna()
# Out:
#     Name    Age  marks
# 0  False  False   True
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df.isna().sum()
# Out:
# Name     0
# Age      0
# marks    1
# dtype: int64

# %%
df.dropna()
# Out:
#       Name  Age  marks
# 1    surya   20   75.0
# 2    pavan   21   69.0
# 3  lakshmi   25   85.0

# %%
df.dropna(axis=True)
# Out:
#       Name  Age
# 0  Bhaskar   23
# 1    surya   20
# 2    pavan   21
# 3  lakshmi   25

# %%
df.dropna(axis=0)
# Out:
#       Name  Age  marks
# 1    surya   20   75.0
# 2    pavan   21   69.0
# 3  lakshmi   25   85.0

# %%
df.dropna(subset="marks")
# Out:
#       Name  Age  marks
# 1    surya   20   75.0
# 2    pavan   21   69.0
# 3  lakshmi   25   85.0

# %%
df.at[2,'marks']=85
df
# Out:
#       Name  Age  marks
# 0  Bhaskar   23    NaN
# 1    surya   20   75.0
# 2    pavan   21   85.0
# 3  lakshmi   25   85.0

# %%
df.fillna(28.999)
# Out:
#       Name  Age   marks
# 0  Bhaskar   23  28.999
# 1    surya   20  75.000
# 2    pavan   21  85.000
# 3  lakshmi   25  85.000

# %%
df.rename(columns={"Name":"Student"}, inplace=True)
df
# Out:
#    Student  Age  marks
# 0  Bhaskar   23    NaN
# 1    surya   20   75.0
# 2    pavan   21   85.0
# 3  lakshmi   25   85.0

# %%
df['Student']= df['Student'].str.upper()
df
# Out:
#    Student  Age  marks
# 0  BHASKAR   23    NaN
# 1    SURYA   20   75.0
# 2    PAVAN   21   85.0
# 3  LAKSHMI   25   85.0

# %%
df['Student']= df['Student'].str.lower()
df
# Out:
#    Student  Age  marks
# 0  bhaskar   23    NaN
# 1    surya   20   75.0
# 2    pavan   21   85.0
# 3  lakshmi   25   85.0

# %%
import pandas as pd
a=pd.read_csv('/content/infosys.csv')
print(a)
# Out:
#    rool number     name  age  marks
# 0           56  bhaskar   21     35
# 1           57     raju   21     35

# %%
import pandas as pd
data = {'student':['bhaskar','ram','pavan','swapna','geetha','surya','bhaskar'],
        'age':[24,23,22,23,23,'nan','nan'],
        'rool_no':[56,57,58,59,50,60,76],
        'marks':[60,75,90,55,'nan',66,77]}
df=pd.DataFrame(data)
df.to_csv('first.csv',index=False)
print(data)
# Out:
# {'student': ['bhaskar', 'ram', 'pavan', 'swapna', 'geetha', 'surya', 'bhaskar'], 'age': [24, 23, 22, 23, 23, 'nan', 'nan'], 'rool_no': [56, 57, 58, 59, 50, 60, 76], 'marks': [60, 75, 90, 55, 'nan', 66, 77]}

# %%
import pandas as pd
a=pd.read_csv('/content/first.csv')
print(a)
# Out:
#    student   age  rool_no  marks
# 0  bhaskar  24.0       56   60.0
# 1      ram  23.0       57   75.0
# 2    pavan  22.0       58   90.0
# 3   swapna  23.0       59   55.0
# 4   geetha  23.0       50    NaN
# 5    surya   NaN       60   66.0
# 6  bhaskar   NaN       76   77.0

# %%
newdf = a.fillna(22.00)
print(newdf)
# Out:
#    student   age  rool_no  marks
# 0  bhaskar  24.0       56   60.0
# 1      ram  23.0       57   75.0
# 2    pavan  22.0       58   90.0
# 3   swapna  23.0       59   55.0
# 4   geetha  23.0       50   22.0
# 5    surya  22.0       60   66.0
# 6  bhaskar  22.0       76   77.0

# %%
newdf.iloc[4,3]=85.0
newdf.iloc[5,3]=70.0
newdf
# Out:
#    student   age  rool_no  marks
# 0  bhaskar  24.0       56   60.0
# 1      ram  23.0       57   75.0
# 2    pavan  22.0       58   90.0
# 3   swapna  23.0       59   55.0
# 4   geetha  23.0       50   85.0
# 5    surya  22.0       60   70.0
# 6  bhaskar  22.0       76   77.0

# %%
a.fillna({'age':22,'marks':85},inplace=False)
# Out:
#    student   age  rool_no  marks
# 0  bhaskar  24.0       56   60.0
# 1      ram  23.0       57   75.0
# 2    pavan  22.0       58   90.0
# 3   swapna  23.0       59   55.0
# 4   geetha  23.0       50   85.0
# 5    surya  22.0       60   66.0
# 6  bhaskar  22.0       76   77.0

# %%
print(a.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
#data cleaning
df_cleaned=a.drop('age',axis=1)
df_cleaned
# Out:
#    student  rool_no  marks
# 0  bhaskar       56   60.0
# 1      ram       57   75.0
# 2    pavan       58   90.0
# 3   swapna       59   55.0
# 4   geetha       50   85.0
# 5    surya       60   66.0
# 6  bhaskar       76   77.0

# %%
df_cleaned1=newdf.drop('marks',axis=1)

# %%
print(df_cleaned1)
# Out:
#    student   age  rool_no
# 0  bhaskar  24.0       56
# 1      ram  23.0       57
# 2    pavan  22.0       58
# 3   swapna  23.0       59
# 4   geetha  23.0       50
# 5    surya  22.0       60
# 6  bhaskar  22.0       76

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# student    0
# age        0
# rool_no    0
# marks      0
# dtype: int64
