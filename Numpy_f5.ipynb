# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentorLive/Reality_AI/blob/NITISHA_SHINY/Numpy_f5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np

# %%
list=[1000,2000,3000,4000]
list1=[250,200,350,400]
n=np.array([list,list1])

# %%
n
# Out:
# array([[1000, 2000, 3000, 4000],
#        [ 250,  200,  350,  400]])

# %%
n.ndim
# Out:
# 2

# %%
n.size
# Out:
# 8

# %%
n.shape
# Out:
# (2, 4)

# %%
arr = np.array(["1", 2, 3, 5]).reshape(1,1,1,1,4)
print(arr, arr.dtype)
# Out:
# [[[[['1' '2' '3' '5']]]]] <U21

# %%
name="Nitishashiny"
d=np.fromiter(name,dtype='U2')
d
# Out:
# array(['N', 'i', 't', 'i', 's', 'h', 'a', 's', 'h', 'i', 'n', 'y'],
#       dtype='<U2')

# %%
f=np.arange(2,11)
f
# Out:
# array([ 2,  3,  4,  5,  6,  7,  8,  9, 10])

# %%
f=np.arange(start=2,stop=10,step=2)
f
# Out:
# array([2, 4, 6, 8])

# %%
arr=np.array([2,1,4,5,6,7,8,8])
np.sort(arr)
# Out:
# array([1, 2, 4, 5, 6, 7, 8, 8])

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
x = np.array([[1,2],[3,5]])
y = np.array([[10,20],[30,50]])

result = np.concatenate((x, y), axis=1)
print(result)
# Out:
# [[ 1  2 10 20]
#  [ 3  5 30 50]]

# %%
import numpy as np
iterable=(x*x for x in range(10))
np.fromiter(iterable,dtype=int)
arr
# Out:
# array([2, 1, 4, 5, 6, 7, 8, 8])

# %%
import numpy as np
data=np.arange(1,10)
output=np.average(data)
print(data)
print(output)
# Out:
# [1 2 3 4 5 6 7 8 9]
# 5.0

# %%
import numpy as np
arr1=np.array([23,45,6,67])
arr2=np.array([90,78,67,55])
arr=np.stack((arr1,arr2),axis=0)
print(arr)
# Out:
# [[23 45  6 67]
#  [90 78 67 55]]

# %%
import numpy as np
arr1=np.array([23,45,6,67])
arr2=np.array([90,78,67,55])
arr=np.stack((arr1,arr2),axis=1)
print(arr)
# Out:
# [[23 90]
#  [45 78]
#  [ 6 67]
#  [67 55]]

# %%
import numpy as np
arr1=np.array([23,45,6,67])
arr2=np.array([90,78,67,55])
arr=np.hstack((arr1,arr2))
print(arr)
# Out:
# [23 45  6 67 90 78 67 55]

# %%
import numpy as np
arr1=np.array([23,45,6,67])
arr2=np.array([90,78,67,55])
arr=np.vstack((arr1,arr2))
print(arr)
# Out:
# [[23 45  6 67]
#  [90 78 67 55]]

# %%
import numpy as np
arr1=np.array([23,45,6,67])
arr2=np.array([90,78,67,55])
arr=np.dstack((arr1,arr2))
print(arr)
# Out:
# [[[23 90]
#   [45 78]
#   [ 6 67]
#   [67 55]]]

# %%
import numpy as np
arr=np.array([23,45,6,67,6,7])
newarr=np.array_split(arr,2)
print (newarr)
# Out:
# [array([23, 45,  6]), array([67,  6,  7])]

# %%
import numpy as np
arr=np.array([23,45,6,67,6,7])
newarr=np.array_split(arr,3)
print (newarr[0])
print (newarr[1])
print (newarr[2])
# Out:
# [23 45]
# [ 6 67]
# [6 7]

# %%
import numpy as np
arr=np.array([23,45,6,67,6,7])
newarr=np.array_split(arr,7)
print (newarr)
# Out:
# [array([23]), array([45]), array([6]), array([67]), array([6]), array([7]), array([], dtype=int64)]

# %%
import numpy as np
arr=np.array([23,45,6,67,6,7])
newarr=np.array_split(arr,7)
print (newarr[0])
print (newarr[1])
print (newarr[2])
# Out:
# [23]
# [45]
# [6]

# %%
arr=np.array([[50,40],[40,67],[89,67],[1,2],[78,56]])
newarr=np.array_split(arr,3)
print(newarr)
# Out:
# [array([[50, 40],
#        [40, 67]]), array([[89, 67],
#        [ 1,  2]]), array([[78, 56]])]

# %%
arr=np.array([[50,40],[40,67],[89,67],[1,2],[78,56]])
newarr=np.array_split(arr,7)
print(newarr)
# Out:
# [array([[50, 40]]), array([[40, 67]]), array([[89, 67]]), array([[1, 2]]), array([[78, 56]]), array([], shape=(0, 2), dtype=int64), array([], shape=(0, 2), dtype=int64)]
