# %%
#import these modules

from nltk.stem import WordNetLemmatizer

import nltk

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

print("rocks:", lemmatizer.lemmatize("rocks"))

print("corpora", lemmatizer.lemmatize("corpora"))

#a denotes adjective in "pos"

print("better:", lemmatizer.lemmatize("better", pos="a"))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# rocks: rock
# corpora corpus
# better: good

# %%
from nltk.stem import PorterStemmer

# Create a Porter Stemmer instance

porter_stemmer = PorterStemmer()

# Example words for stemming

words = ["running", "jumps", "happily", "running", "happily"]

# Apply stemming to each word

stemmed_words = [porter_stemmer.stem(word) for word in words]

# Print the results

print("Original words:", words)

print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['running', 'jumps', 'happily', 'running', 'happily']
# Stemmed words: ['run', 'jump', 'happili', 'run', 'happili']

# %%
from nltk.stem import PorterStemmer

#Create a PorterStemmer instance
porter_stemmer = PorterStemmer()

# Create words.txt with some example content
with open("words.txt", "w") as file:
    file.write("running jumps happily cats dogs")

# Read words from a text file
with open("words.txt", "r") as file:
    text = file.read()

# Split words by space or newline
words = text.split()

# Apply stemming
stemmed_words = [porter_stemmer.stem(word) for word in words]

#Print results
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['running', 'jumps', 'happily', 'cats', 'dogs']
# Stemmed words: ['run', 'jump', 'happili', 'cat', 'dog']
