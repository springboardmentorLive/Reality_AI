# %%
import pandas as pd
data = {'Name': ['Shiv', 'Vishnu', 'Lakshmi', 'Saras'],
        'Age': [25, None, 30, None],
        'Gender': ['M', 'M', None, 'F']}
print(data)
# Out:
# {'Name': ['Shiv', 'Vishnu', 'Lakshmi', 'Saras'], 'Age': [25, None, 30, None], 'Gender': ['M', 'M', None, 'F']}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age Gender
# 0     Shiv  25.0      M
# 1   Vishnu   NaN      M
# 2  Lakshmi  30.0   None
# 3    Saras   NaN      F

# %% [markdown]
# Step-by-Step Data Cleaning Methods
#
# Check for Missing Data bold text
#
# Shows which cells are missing (True)
# Summarizes how many missing values per column -- isna()

# %%
df.isna()
# Out:
#     Name    Age  Gender
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3  False   True   False

# %%
df.isna()
# Out:
#     Name    Age  Gender
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3  False   True   False

# %% [markdown]
# 2. Drop Missing Data 🔹 Drop Rows with Any NaN

# %%
df.dropna()
# Out:
#    Name   Age Gender
# 0  Shiv  25.0      M

# %% [markdown]
#  Drop Columns with Any NaN

# %%
df.dropna(axis=1)
# Out:
#       Name
# 0     Shiv
# 1   Vishnu
# 2  Lakshmi
# 3    Saras

# %% [markdown]
#  Drop Rows with Missing in Specific Column

# %%
 df.dropna(subset=['Age'])
# Out:
#       Name   Age Gender
# 0     Shiv  25.0      M
# 2  Lakshmi  30.0   None

# %%
df.at[1,'Gender']='F'
df
# Out:
#       Name   Age Gender
# 0     Shiv  25.0      M
# 1   Vishnu   NaN      F
# 2  Lakshmi  30.0   None
# 3    Saras   NaN      F

# %% [markdown]
# Fill Missing Data (Imputation) 🔹 Fill with a Constan

# %%
df.fillna(0)
# Out:
#       Name   Age Gender
# 0     Shiv  25.0      M
# 1   Vishnu   0.0      F
# 2  Lakshmi  30.0      0
# 3    Saras   0.0      F

# %% [markdown]
# Mean/Median/Mode

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3663963327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# /tmp/ipython-input-3663963327.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Detect Duplicates

# %%
df.duplicated()
#df.drop_duplicates()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age Gender
# 0     Shiv  25.0      M
# 1   Vishnu  27.5      F
# 2  Lakshmi  30.0      F
# 3    Saras  27.5      F

# %% [markdown]
# Convert Data Types

# %%
df['Age'] = df['Age'].astype(int)

# %% [markdown]
# 6. Rename Columns

# %%
df.rename(columns={'Name': 'FullName'}, inplace=True)
df      upper()----lower()
# Out:
#   FullName   Age Gender
# 0     Shiv  25.0      M
# 1   Vishnu   NaN      M
# 2  Lakshmi  30.0   None
# 3    Saras   NaN      F

# %% [markdown]
# 7. Standardize Text

# %%
df['FullName'] = df['FullName'].str.upper()
df
# Out:
#   FullName   Age Gender
# 0     SHIV  25.0      M
# 1   VISHNU   NaN      M
# 2  LAKSHMI  30.0   None
# 3    SARAS   NaN      F

# %% [markdown]
# 8.Remove Outliers (Optional)

# %%
df = df[df['Age'] < 100]  # Example filter

# %%
df
# Out:
#       Name  Age Gender
# 0     Shiv   25      M
# 1   Vishnu   27      F
# 2  Lakshmi   30      F
# 3    Saras   27      F

# %% [markdown]
# USING CSV FILE

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Book1.csv')

# %%
print(df)
# Out:
#    Name  Age  Salary
# 0  abhi   21  289999
