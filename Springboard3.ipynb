# %% [markdown]
# # 24/12
# Hand Gesture Recognition

# %%
# %pip install pyttsx3
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.31-py3-none-win_amd64.whl.metadata (9.7 kB)
# Collecting pyttsx3
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting absl-py~=2.3 (from mediapipe)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (1.26.3)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.5.3)
# Collecting flatbuffers~=25.9 (from mediapipe)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from sounddevice~=0.5->mediapipe) (1.17.1)
# Collecting comtypes (from pyttsx3)
#   Using cached comtypes-1.4.14-py3-none-any.whl.metadata (7.3 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from pyttsx3) (311)
# Requirement already satisfied: pycparser in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe) (2.22)
# Using cached mediapipe-0.10.31-py3-none-win_amd64.whl (10.4 MB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading comtypes-1.4.14-py3-none-any.whl (254 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: flatbuffers, pypiwin32, comtypes, absl-py, pyttsx3, mediapipe
#
#   Attempting uninstall: flatbuffers
#
#     Found existing installation: flatbuffers 24.3.25
#
#     Uninstalling flatbuffers-24.3.25:
#
#       Successfully uninstalled flatbuffers-24.3.25
#
#    ---------------------------------------- 0/6 [flatbuffers]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#    ------------- -------------------------- 2/6 [comtypes]
#   Attempting uninstall: absl-py
#    ------------- -------------------------- 2/6 [comtypes]
#     Found existing installation: absl-py 2.1.0
#    ------------- -------------------------- 2/6 [comtypes]
#    -------------------- ------------------- 3/6 [absl-py]
#     Uninstalling absl-py-2.1.0:
#    -------------------- ------------------- 3/6 [absl-py]
#       Successfully uninstalled absl-py-2.1.0
#    -------------------- ------------------- 3/6 [absl-py]
#    -------------------- ------------------- 3/6 [absl-py]
#    -------------------- ------------------- 3/6 [absl-py]
#    -------------------------- ------------- 4/6 [pyttsx3]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    --------------------------------- ------ 5/6 [mediapipe]
#    ---------------------------------------- 6/6 [mediapipe]
#
# Successfully installed absl-py-2.3.1 comtypes-1.4.14 flatbuffers-25.12.19 mediapipe-0.10.31 pypiwin32-223 pyttsx3-2.99
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip uninstall mediapipe -y
# Out:
# Found existing installation: mediapipe 0.10.31
# Uninstalling mediapipe-0.10.31:
#   Successfully uninstalled mediapipe-0.10.31
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade mediapipe
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.31-py3-none-win_amd64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py~=2.3 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: numpy in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (1.26.3)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: CFFI>=1.0 in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from sounddevice~=0.5->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\saina\appdata\local\programs\python\python311\lib\site-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe) (2.22)
# Using cached mediapipe-0.10.31-py3-none-win_amd64.whl (10.4 MB)
# Installing collected packages: mediapipe
# Successfully installed mediapipe-0.10.31
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~roq (c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import mediapipe as mp
import pyttsx3
import time

# Initialize TTS
engine = pyttsx3.init()
engine.setProperty('rate', 160)

def speak(text):
    engine.say(text)
    engine.runAndWait()

# MediaPipe setup
mp_hands = mp.solutions.hands
mp_draw = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

def recognize_gesture(landmarks):
    tips = [4, 8, 12, 16, 20]
    fingers = []

    # Thumb (right hand logic)
    fingers.append(1 if landmarks[4].x < landmarks[3].x else 0)

    # Other fingers
    for tip in tips[1:]:
        fingers.append(1 if landmarks[tip].y < landmarks[tip - 2].y else 0)

    if fingers == [1, 1, 1, 1, 1]:
        return "Hi"
    elif fingers == [1, 0, 0, 0, 0]:
        return "Thumbs Up"
    elif fingers == [0,0,0,0,0]:
        return "Fist"
    elif fingers == [0,1,1,0,0]:
        return "Peace"
    else:
        return None


gesture_speech = {
    "Hi": "Hello there!",
    "Thumbs Up": "Good job!",
    "Fist": "Ready!",
    "Peace": "Peace!"
}

last_gesture = None
last_time = 0
cooldown = 1.5  # sec

with mp_hands.Hands(
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7,
    max_num_hands=1
) as hands:

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        result = hands.process(rgb)

        gesture_text = "Show a gesture..."

        if result.multi_hand_landmarks:
            hand = result.multi_hand_landmarks[0]
            mp_draw.draw_landmarks (frame, hand, mp_hands.HAND_CONNECTIONS)

            gesture = recognize_gesture(hand.landmark)

            if gesture:
                gesture_text = gesture
                current_time = time.time()

                if gesture != last_gesture and (current_time - last_time) > cooldown:
                    last_gesture = gesture
                    last_time = current_time
                    speak(gesture_speech.get(gesture, gesture))

        cv2.putText(frame, gesture_text, (40, 90),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 4)

        cv2.imshow("AI Gesture to Speech", frame)

        if cv2.waitKey(1) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 15
#      12     engine.runAndWait()
#      14 # MediaPipe setup
# ---> 15 mp_hands = mp.solutions.hands
#      16 mp_draw = mp.solutions.drawing_utils
#      18 cap = cv2.VideoCapture(0)
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %% [markdown]
# # 26/12
# Streamlit Image Uploading

# %%
import streamlit as st
from PIL import Image

st.title("HI")

img = Image.open("C:\\Users\\saina\\Downloads\\figure1_context_timeline.png")
st.image(img, caption="My Image", use_container_width=True)
# Out:
# 2025-12-26 20:46:29.575 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:29.986
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\saina\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-26 20:46:29.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:29.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:30.055 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-12-26 20:46:30.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:30.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:30.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-26 20:46:30.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
