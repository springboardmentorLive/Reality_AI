# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentorLive/Reality_AI/blob/bhaskar/linear_Rig_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd

# %%
data_set = pd.read_csv('/content/salary_dataset.csv')
print(data_set.to_string())
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x=data_set.iloc[:,:-1].values
y=data_set.iloc[:,1].values
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
#splitting data in training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=1/3, random_state=0)
print(x_test,y_test)
# Out:
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]] [ 37731 122391  57081  63218 116969 109431 112635  55794  83088 101302]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=1/5, random_state=1)
print(x_test,y_test)
# Out:
# [[5.3]
#  [7.1]
#  [3.9]
#  [6. ]
#  [4.5]
#  [6.8]] [83088 98273 63218 93940 61111 91738]

# %%
#fitting model into data set
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#result
y_pred=regressor.predict(x_test)
y_pred=regressor.predict(x_train)
print(y_pred)
# Out:
# [114272.87300929  44275.78747434 106806.51721889  99340.1614285
#  102140.0448499   46142.37642194  39609.31510534 109606.40064029
#   53608.73221233  80674.27195251  63874.97142412  55475.32115993
#  115206.16748308  37742.72615775  73207.91616212  35876.13721015
#   71341.32721452 123605.81774728 121739.22879968  60141.79352893
#   55475.32115993  62941.67695033  62941.67695033  52675.43773853]

# %%
#graph of training data
mtp.scatter(x_train,y_train,color="green")
mtp.plot(x_train,regressor.predict(x_train),color="red")
mtp.title("Salary vs Experience(training set)")
mtp.xlabel("years of experience")
mtp.ylabel("salary( in rupes)")
mtp.show()

# %%
#graph of test result
mtp.scatter(x_test,y_test,color="blue")
mtp.plot(x_train,regressor.predict(x_train),color="yellow")
mtp.title("Salary vs Experience(test set)")
mtp.xlabel("years of experience")
mtp.ylabel("salary( in rupes)")
mtp.show()

# %%
import matplotlib
import numpy as nm
import matplotlib.pyplot as plt
from sklearn import  datasets, linear_model
import pandas as pd
#load dataset
df=pd.read_csv('/content/housing_dataset.csv')
y=df['price']
x=df['plotsize']
#reshape forcompatibility with scikit-learn
x=x.to_numpy().reshape(len(x),1)
y=y.to_numpy().reshape(len(y),1)

x_train=x[:2]
x_test=x[2:]
y_train=y[:2]
y_test=y[2:]
#plot the test data
plt.scatter(x_test,y_test,color='blue')
plt.title('Test data')
plt.xlabel('plotsize')
plt.ylabel('price')
plt.xticks(())
plt.yticks(())
#train linear regression
regr=linear_model.LinearRegression()
regr.fit(x_train,y_train)
#plot preditions
plt.plot(x_test,regr.predict(x_test),color='red',linewidth=3)
plt.show()
