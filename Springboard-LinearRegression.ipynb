# %%
import numpy as np
import matplotlib.pyplot as mtp
import pandas as pd

# %%
data_set = pd.read_csv('/content/Salary_Data.csv')
print(data_set.to_string())
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = data_set.iloc[:, :-1].values #Loc (Label- based indexing)
y = data_set.iloc[:, 1].values
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state =0)
print(x_test, y_test)
# Out:
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]] [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.
#  101302.]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
x_pred = regressor.predict(x_train)
print(y_pred)
# Out:
# [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]

# %%
mtp.scatter(x_train, y_train, color = "green")
mtp.plot(x_train, x_pred, color = "red")
mtp.title("Salary vs Experience (Training Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary")
mtp.show()

# %%
#visualizing the Test set results
mtp.scatter(x_test, y_test, color = "blue")
mtp.plot(x_train, x_pred, color = "red")
mtp.title("Salary vs Experience (Test Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary")
mtp.show()

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Create dataset with Experience and Salary
data = {
    'Expierence': [1, 2, 3, 4, 5, 6, 8, 10],
    'Salary': [25000, 30000, 35000, 40000, 45000, 50000, 60000, 70000]
}

df = pd.DataFrame(data)

# Step 2: Define features (X) and target(y)
X = df[['Expierence']]
y = df[['Salary']]

# Step 3: Train Linear Regression model
model  = LinearRegression()
model.fit(X, y)

# Step 4: Predict salary for 7 years of experience
experience_input = [[7]]
predicted_salary = model.predict(experience_input)
print(f"Predicted Salary for 7 years experience: ₹{predicted_salary.item():.2f}")

# Step 5: Visualization
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Regression Line')

plt.scatter(7, predicted_salary.item(), color='green', marker='o', s=100, label='Predicted (7 yrs)')

plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Salary for 7 years experience: ₹55000.00

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Create dataset with Experience and Salary
data = {
    'Expierence': [1, 2, 3, 4, 5, 6, 8, 10],
    'Salary': [25000, 30000, 35000, 40000, 45000, 50000, 60000, 70000]
}

df = pd.DataFrame(data)

# Step 2: Define features (X) and target(y)
X = df[['Expierence']]
y = df[['Salary']]

# Step 3: Train Linear Regression model
model  = LinearRegression()
model.fit(X, y)

# Step 4: Predict salary for 7 years of experience
experience_input = [[11]]
predicted_salary = model.predict(experience_input)
print(f"Predicted Salary for 11 years experience: ₹{predicted_salary.item():.2f}")

# Step 5: Visualization
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Regression Line')

plt.scatter(7, predicted_salary.item(), color='green', marker='o', s=100, label='Predicted ( 11 yrs)')

plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Salary for 11 years experience: ₹75000.00
