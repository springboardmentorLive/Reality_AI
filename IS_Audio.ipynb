# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentorLive/Reality_AI/blob/ananyarohidasshet/IS_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper langdetect pydub

# !apt-get install ffmpeg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 9.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 34.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=f6839b5369743e889bc385c6a5989d87ae2ca7b7fe743a4a5dd67ef3968e856f
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=d37d185698f5654dc61474e9c8d8a9dc0330762953fe82295359e281e85f8723
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# ...

# %%
import whisper
from langdetect import detect, LangDetectException
from pydub import AudioSegment

# # STEP 1: Convert MP3 to WAV
# # ---------------------------------------

audio_path = "/content/ranma_op_dialogue.mp3"
wav_path = "/content/ranma_op_dialogue.wav"

AudioSegment.from_mp3(audio_path).export(wav_path, format="wav")
print("MP3 converted to WAV")

# # STEP 2: Load Whisper model
# # ---------------------------------------
print("Loading Whisper model... (takes 20-30 sec)")
model = whisper.load_model("small") # You can use "base" if GPU is slow

# # STEP 3: Transcribe audio
# # ---------------------------------------
print("Transcribing...")
result = model.transcribe(wav_path)
text = result["text"].strip()

print("\nTranscribed Text:\n", text)

try:

     lang = detect(text)

     print("\nDetected Language Code:", lang)

except LangDetectException:

      print("Error: Could not detect language (text is too short)")
# Out:
# MP3 converted to WAV
# Loading Whisper model... (takes 20-30 sec)
# Transcribing...
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcribed Text:
#  Meet Ronma Sautome of the Anything Goes School of Martial Arts. Here's a conic of the Tendo training hall. What are you doing? The two have been engaged to Mary by their loving parents. I didn't ask for this. Who asked you? Ask for the cause of poor Ronma's suffering. What did you do that for? When Ronma is splashed with cold water, he becomes a she.
#
# Detected Language Code: en
