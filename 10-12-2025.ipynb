# %%
print("Chatbot: Hi! I am your chatbot. Type 'bye' to exit.")
while True:
    user=input("You: ")
    if user.lower()=="hi" or user.lower()=="hello":
        print("Chatbot: Hello! How can I help you?")
    elif user.lower()== "how are you":
        print("Chatbot: I am fine! Thank you")
    elif user.lower()=="bye":
        print("Chatbot: Goodbye! Have a nice day!")
        break 
    else:
        print("Chatbot: Sorry, I don't understand.")
# Out:
# Chatbot: Hi! I am your chatbot. Type 'bye' to exit.

# %%
print("Chatbot: Hi! I am your chatbot. Type 'bye' to exit.")

while True:
    user = input("You: ").lower()

    if user in ("hi", "hello", "hey"):
        print("Chatbot: Hello! How can I help you?")

    elif user == "how are you":
        print("Chatbot: I am fine! Thank you.")

    elif user == "what is your name":
        print("Chatbot: I am your friendly chatbot!")

    elif user == "who created you":
        print("Chatbot: I was created by a Python programmer!")

    elif user == "what can you do":
        print("Chatbot: I can chat with you and answer simple questions!")

    elif user == "tell me a joke":
        print("Chatbot: Why don’t programmers like nature? Too many bugs!")

    elif user == "what is python":
        print("Chatbot: Python is a popular programming language used for AI, web development, and more.")

    elif user == "where are you from":
        print("Chatbot: I live inside your computer!")

    elif user == "who am i":
        print("Chatbot: You are a wonderful human talking to me right now!")

    elif user == "tell me a fact":
        print("Chatbot: Did you know? Python was named after a comedy show, not the snake!")

    elif user == "what is ai":
        print("Chatbot: AI means Artificial Intelligence—machines that can think and learn like humans.")

    elif user == "thank you":
        print("Chatbot: You're welcome!")

    elif user == "bye":
        print("Chatbot: Goodbye! Have a nice day!")
        break

    else:
        print("Chatbot: Sorry, I don't understand.")
# Out:
# Chatbot: Hi! I am your chatbot. Type 'bye' to exit.
# Chatbot: Sorry, I don't understand.
# Chatbot: Sorry, I don't understand.

# %%
class ChatBot:
    def __init__(self):
        # Group questions that should have the same answer
        self.responses = {
            
            # 1. Name related questions
            "My name is ChatBot!": [
                "what is your name",
                "what's your name",
                "who are you",
                "tell me your name",
                "your name"
            ],

            # 2. Feeling / how are you questions
            "I'm doing great, thanks!": [
                "how are you",
                "how are you doing",
                "how do you feel",
                "are you ok",
                "how's it going"
            ],

            # 3. Purpose related questions
            "I'm a chatbot created to help you!": [
                "what are you",
                "what do you do",
                "what is your purpose",
                "why do you exist"
            ],
        }

    def get_response(self, user_input):
        user_input = user_input.lower().strip()

        # Search in grouped responses
        for response, questions in self.responses.items():
            if user_input in questions:
                return response
        
        return "Sorry, I don't understand."

# -------- RUN THE CHATBOT ---------

bot = ChatBot()
print("Chatbot: Hello! Type 'bye' to exit.")

while True:
    user = input("You: ").strip().lower()

    if user == "bye":
        print("Chatbot: Goodbye! Have a great day!")
        break
    print("Chatbot:", bot.get_response(user))
# Out:
# Chatbot: Hello! Type 'bye' to exit.
# Chatbot: I'm doing great, thanks!
# Chatbot: I'm a chatbot created to help you!
# Chatbot: My name is ChatBot!

# %%
class ChatBot:
    def __init__(self):
        # Group questions that should have the same answer
        self.responses = {
            
            # 1. Name related questions
            "My name is ChatBot!": [
                "what is your name",
                "what's your name",
                "who are you",
                "tell me your name",
                "your name"
            ],

            # 2. Feeling / how are you questions
            "I'm doing great, thanks!": [
                "how are you",
                "how are you doing",
                "how do you feel",
                "are you ok",
                "how's it going"
            ],

            # 3. Purpose related questions
            "I'm a chatbot created to help you!": [
                "what are you",
                "what do you do",
                "what is your purpose",
                "why do you exist"
            ],

            # 4. Creator related questions
            "I was created by a Python developer!": [
                "who created you",
                "who made you",
                "who developed you"
            ],

            # 5. Weather questions
            "I don't have senses, but I hope the weather is nice where you are!": [
                "how is the weather",
                "what's the weather",
                "is it raining",
                "is it hot today"
            ],

            # 6. Joke questions
            "Here’s a joke: Why do programmers hate nature? Too many bugs!": [
                "tell me a joke",
                "say a joke",
                "make me laugh",
                "joke"
            ],

            # 7. Time questions
            "I don’t keep track of time, but you can check your clock!": [
                "what's the time",
                "tell me the time",
                "time please"
            ],

            # 8. About Python
            "Python is a powerful programming language used for AI, ML, and web development!": [
                "what is python",
                "tell me about python",
                "python language"
            ],

            # 9. Gratitude response
            "You're welcome! Happy to help 😊": [
                "thank you",
                "thanks",
                "thank u"
            ],
        }

    def get_response(self, user_input):
        user_input = user_input.lower().strip()

        # Search in grouped responses
        for response, questions in self.responses.items():
            if user_input in questions:
                return response
        
        return "Sorry, I don't understand."

# -------- RUN THE CHATBOT ---------

bot = ChatBot()
print("Chatbot: Hello! Type 'bye' to exit.")

while True:
    user = input("You: ").strip().lower()

    if user == "bye":
        print("Chatbot: Goodbye! Have a great day!")
        break
    
    print("Chatbot:", bot.get_response(user))
# Out:
# Chatbot: Hello! Type 'bye' to exit.
# Chatbot: My name is ChatBot!
# Chatbot: I'm doing great, thanks!
# Chatbot: I'm a chatbot created to help you!
# Chatbot: I was created by a Python developer!
# Chatbot: I don't have senses, but I hope the weather is nice where you are!
# Chatbot: Here’s a joke: Why do programmers hate nature? Too many bugs!
# Chatbot: I don’t keep track of time, but you can check your clock!
# Chatbot: Python is a powerful programming language used for AI, ML, and web development!
