# %%
import pandas as pd

import matplotlib.pyplot as plt

from matplotlib import style

# %%
time_data={'facebook':120, 'youtube' :90, 'instagram':40, 'snapchat':28}

social_media=list(time_data.keys())

time_speed=list(time_data.values())

# %%
plt.bar(social_media,time_speed)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(social_media,time_speed,color='green')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xlabel('social media')

plt.ylabel('time')

plt.title('average time speed on social media')
plt.bar(social_media,time_speed,color='green')
# Out:
# <BarContainer object of 4 artists>

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
color=['blue','red','pink','yellow']
plt.bar(social_media,time_speed,color=color,width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
style.use('ggplot')

plt.figure(figsize=(5,5))

plt.bar(xpos,facebook, color="blue", width=0.25, label='FB')

plt.bar(xpos+0.2, youtube, color="red", width=0.25, label='YT')

plt.bar(xpos+0.4,instagram, color="pink", width=0.25, label='LG')

plt.bar(xpos+0.6,snapchat,color="yellow", width=0.25, label='SC')

plt.xlabel('day')

plt.ylabel("time speed in minits")

plt.legend()

plt.title("bar chat")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-147131998.py in <cell line: 0>()
# ----> 1 style.use('ggplot')
#       2
#       3 plt.figure(figsize=(5,5))
#       4
#       5 plt.bar(xpos,facebook, color="blue", width=0.25, label='FB')
#
# NameError: name 'style' is not defined

# %%
import matplotlib.pyplot as plt
labels = ['pizza', 'biryani', 'icecream', 'choclate', 'burger']
sizes = [18.00, 19.00, 20.00, 30.20, 20.00]
plt.axis('equal')
plt.pie(sizes, labels=labels, autopct='%1.2f%%', startangle=90)
plt.title('Marks of a Student')
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
import matplotlib.pyplot as plt
import csv

Subjects = []
Scores = []

with open('Book2.csv', 'r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        Subjects.append(row[0])
        Scores.append(int(row[1]))
plt.bar(Subjects, Scores, color=['blue', 'green', 'red', 'purple'])
plt.title('Marks of a Student', fontsize=20)
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd.Series(4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.pie(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"],name="series")

series.plot.area(figsize=(5,5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.barh(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.box(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.hist(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.kde(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.density(figsize=(5, 5));

plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

series = pd. Series (4 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.line(figsize=(5, 5));

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data_set = {'names': ['siva', 'nani', 'sai', 'sai'], 'age': [22, 32, 44, 44], 'gender': ['m', 'm', 'f', 'f']}
data = pd.DataFrame(data_set)
plt.figure(figsize=(8, 6))
plt.bar(data['names'], data['age'])
plt.title('Age of Each Person')
plt.xlabel('Names')
plt.ylabel('Age')
plt.show()

# %%
data_set = {'names': ['siva', 'nani', 'sai', 'sai'], 'age': [22, 32, 44, 44], 'gender': ['m', 'm', 'f', 'f']}
data = pd.DataFrame(data_set)
duplicates = data[data.duplicated()]
print("Duplicate rows:")
print(duplicates)
# Out:
# Duplicate rows:
#   names  age gender
# 3   sai   44      f

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_set = {'names': ['siva', 'nani', 'sai', 'sai'], 'age': [22, 32, 44, 44], 'gender': ['m', 'm', 'f', 'f']}
data = pd.DataFrame(data_set)
data = data.drop_duplicates(ignore_index=True)
print(data)
plt.figure(figsize=(8, 6))
plt.bar(data['names'], data['age'])
plt.title('Age of Each Person')
plt.xlabel('Names')
plt.ylabel('Age')
plt.show()
# Out:
#   names  age gender
# 0  siva   22      m
# 1  nani   32      m
# 2   sai   44      f

# %%
import pandas as pd
import numpy as np
import csv
data = {
    'Name': ['Riya', 'Karan', None, 'Meena', 'Amit', None, 'Sneha', 'Vikas', 'Neha', 'Tina'],
    'Age': [28, 30, 22, None, 26, 21, None, 24, 29, None],
    'Gender': ['F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'F', 'F'],
    'Score': [91, None, 76, 84, 89, 95, None, 88, 93, 90]
}
df = pd.DataFrame(data)
df.to_csv("raw_data.csv")

# %%
df=pd.read_csv("raw_data.csv")
df.head(5)
# Out:
#    Unnamed: 0   Name   Age Gender  Score
# 0           0   Riya  28.0      F   91.0
# 1           1  Karan  30.0      M    NaN
# 2           2    NaN  22.0      M   76.0
# 3           3  Meena   NaN      F   84.0
# 4           4   Amit  26.0      M   89.0

# %%
df.dropna()
# Out:
#    Unnamed: 0   Name   Age Gender  Score
# 0           0   Riya  28.0      F   91.0
# 4           4   Amit  26.0      M   89.0
# 7           7  Vikas  24.0      M   88.0
# 8           8   Neha  29.0      F   93.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          2
# Age           3
# Gender        0
# Score         2
# dtype: int64

# %%
cleaned_df = df.copy()

cleaned_df["Name"].fillna("Anshu", inplace=True)
cleaned_df["Age"].fillna(21,inplace=True)
cleaned_df
# Out:
# /tmp/ipython-input-1936749780.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_df["Name"].fillna("Anshu", inplace=True)
# /tmp/ipython-input-1936749780.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
cleaned_df.to_csv("cleaned_data.csv")

# %%
import cv2 #- cv2: Imports OpenCV, a powerful library for image and video processing.
import os
#Path to your video file
video_path = "/content/AIvideo.mp4"
# Folder to save extracted frames
output_folder = "frames"
#Create the folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)
# Load the video
cap = cv2.VideoCapture("/content/AIvideo.mp4")
#Check if video opened successfully
if not cap.isOpened():
  print("Error: Could not open video.")
  exit()
frame_count = 0
while True:
  ret, frame = cap.read()
  if not ret:
    break # End of video
    # Save frame as image
    frame_filename = os.path.join(output_folder, f"frame_{frame_count:03d}.jpg")
    cv2.imwrite(frame_filename, frame)
    print(f"Saved {frame_filename}")
    frame_count += 1
# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import pandas as pd
import numpy as np
data_set = {'names': ['siva', 'nani', 'sai', 'sai', 'raj'],
            'age': [22, 32, 44, 44, None],
            'gender': ['m', 'm', 'f', 'f', 'm']}
data = pd.DataFrame(data_set)
data = data.drop_duplicates(ignore_index=True)
print("Data after dropping duplicates:")
print(data)
print("-" * 30)
data_filled = data.fillna({'age': 30})
print("Data after filling NaN values with 30:")
print(data_filled)
print("-" * 30)

csv_filename = 'data_with_nans_filled.csv'
data_filled.to_csv(csv_filename, index=False)
print(f"Final data successfully saved to {csv_filename}")
# Out:
# Data after dropping duplicates:
#   names   age gender
# 0  siva  22.0      m
# 1  nani  32.0      m
# 2   sai  44.0      f
# 3   raj   NaN      m
# ------------------------------
# Data after filling NaN values with 30:
#   names   age gender
# 0  siva  22.0      m
# 1  nani  32.0      m
# 2   sai  44.0      f
# 3   raj  30.0      m
# ------------------------------
# Final data successfully saved to data_with_nans_filled.csv
