# %%
print("Chatbot: Hi! I am your chatbot. Type 'bye' to exit.")
while True:
  user = input("You: ")
  if user.lower() == "hi" or user.lower()=="hello" or user.lower()=="hy":
    print("Chatbot: Hello! How can I help you?")
  elif user.lower() == "how are you":
    print("Chatbot: I am fine! Thank you")
  elif user.lower() == "bye":
    print("Chatbot: Goodbye! Have a nice day!")
    break
  else:
    print("Chatbot: Sorry, I don't understand.")
# Out:
# Chatbot: Hi! I am your chatbot. Type 'bye' to exit.
# You: hy
# Chatbot: Hello! How can I help you?
# You: hello
# Chatbot: Hello! How can I help you?
# You: bye
# Chatbot: Goodbye! Have a nice day!

# %%
print("Chatbot: Hi! I am your chatbot. Type 'bye' to exit.")
while True:
  user = input("You: ")
  user=user.lower()
  greetings=["hi","hello","hy","hey"]
  if user in greetings:
    print("Chatbot: Hello! How can I help you?")
  elif user == "how are you":
    print("Chatbot: I am fine! Thank you")
  elif user == "bye":
    print("Chatbot: Goodbye! Have a nice day!")
    break
  else:
    print("Chatbot: Sorry, I don't understand.")
# Out:
# Chatbot: Hi! I am your chatbot. Type 'bye' to exit.
# You: hey
# Chatbot: Hello! How can I help you?
# You: bye
# Chatbot: Goodbye! Have a nice day!

# %%
class ChatBot:
    def __init__(self):
        self.responses = {
            "My name is ChatBot!": [
                "what is your name",
                "what's your name",
                "who are you",
                "tell me your name",
                "your name"
            ],
            "I'm doing great, thanks!": [
                "how are you",
                "how are you doing",
                "how do you feel",
                "are you ok",
                "how's it going"
            ],
            "I'm a chatbot created to help you!": [
                "what are you",
                "what do you do",
                "what is your purpose",
                "what can you do",
                "why do you exist"
            ]
        }
    def get_response(self, user_input):
        user_input = user_input.lower().strip()
        for answer, questions in self.responses.items():
            if any(question in user_input for question in questions):
                return answer
        return "I'm sorry, I don't understand."
bot = ChatBot()
print(bot.get_response("what is your name"))
print(bot.get_response("who are you"))
print(bot.get_response("how are you"))
print(bot.get_response("how can i help you"))
# Out:
# My name is ChatBot!
# My name is ChatBot!
# I'm doing great, thanks!
# I'm sorry, I don't understand.

# %%
class ChatBot:
    def __init__(self):
        self.responses = {
            "My name is ChatBot!": [
                "what is your name",
                "what's your name",
                "who are you",
                "tell me your name",
                "your name"
            ],
            "I'm doing great, thanks!": [
                "how are you",
                "how are you doing",
                "how do you feel",
                "are you ok",
                "how's it going"
            ],
            "I'm a chatbot created to help you!": [
                "what are you",
                "what do you do",
                "what is your purpose",
                "what can you do",
                "why do you exist"
            ],
            "Hello! How can I help you?": [
                "hi",
                "hello",
                "hey",
                "hy",
                "hii",
                "heyy"
            ],
            "I don't have an age, I'm just code!": [
                "how old are you",
                "your age",
                "what is your age"
            ],
            "You're welcome!": [
                "thank you",
                "thanks",
                "thx",
                "thankyou"
            ],
            "I can't check weather yet, but I hope it's nice where you are!": [
                "weather",
                "how is the weather",
                "today's weather"
            ],
            "I can answer simple questions. Try asking 'what is your name?'": [
                "help me",
                "help",
                "what can you do"
            ]
        }
    def get_response(self, user_input):
        user_input = user_input.lower().strip()
        for answer, questions in self.responses.items():
            if any(question in user_input for question in questions):
                return answer
        return "I'm sorry, I don't understand."
bot = ChatBot()
print(bot.get_response("hi"))
print(bot.get_response("how old are you"))
print(bot.get_response("what can you do"))
print(bot.get_response("tell me a joke"))
print(bot.get_response("thank you"))
print(bot.get_response("who are you"))
print(bot.get_response("how are you"))
print(bot.get_response("weather today"))
print(bot.get_response("something unknown"))
# Out:
# Hello! How can I help you?
# I don't have an age, I'm just code!
# I'm a chatbot created to help you!
# I'm sorry, I don't understand.
# You're welcome!
# My name is ChatBot!
# I'm doing great, thanks!
# I can't check weather yet, but I hope it's nice where you are!
# Hello! How can I help you?

# %%
class ChatBot:
    def __init__(self):
        self.responses = {
            "Hello! How can I help you?": [
                "hi", "hello", "hey", "hy", "hii", "heyy"
            ],
            "My name is ChatBot. Nice to meet you!": [
                "what is your name", "your name", "who are you"
            ],
            "I'm doing well! Thanks for asking.": [
                "how are you", "how are you doing", "are you fine"
            ],
            "Good morning! Have a great day ahead!": [
                "good morning", "gm"
            ],
            "Good night! Sleep well!": [
                "good night", "gn"
            ],
            "Thank you! You're kind!": [
                "you are nice", "you are good", "you are smart"
            ],
            "Believe in yourself! You can do anything.": [
                "motivate me", "motivation", "give me motivation"
            ],
            "I like talking about food! What's your favourite dish?": [
                "do you like food", "do you eat", "food"
            ],
            "Pizza is amazing! I hope you enjoy it too.": [
                "i like pizza", "pizza"
            ],
            "That's great! Hobbies make life fun!": [
                "i like music", "i like dancing", "i like reading"
            ],
            "2 + 2 = 4 (Easy one!)": [
                "what is 2+2", "2+2"
            ],
            "10 - 3 = 7": [
                "what is 10-3", "10-3"
            ],
            "5 * 5 = 25": [
                "what is 5*5", "5*5"
            ]
        }
    def get_response(self, user_input):
        user_input = user_input.lower().strip()
        for answer, questions in self.responses.items():
            if any(q in user_input for q in questions):
                return answer
        return "Hmm... I don't understand that yet."
bot = ChatBot()
print(bot.get_response("good morning"))
print(bot.get_response("i like pizza"))
print(bot.get_response("motivate me"))
print(bot.get_response("what is 2+2"))
print(bot.get_response("hello"))
print(bot.get_response("i like dancing"))
# Out:
# Good morning! Have a great day ahead!
# Pizza is amazing! I hope you enjoy it too.
# Believe in yourself! You can do anything.
# 2 + 2 = 4 (Easy one!)
# Hello! How can I help you?
# That's great! Hobbies make life fun!
