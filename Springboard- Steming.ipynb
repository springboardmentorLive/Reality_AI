# %%
from nltk.stem import PorterStemmer

porter_stemmer = PorterStemmer()

words = ["running", "jumps", "happily", "running", "happily"]
stemmed_words = [porter_stemmer.stem(word) for word in words]

print("Original words: ", words)
print("Stemmed words: ", stemmed_words)
# Out:
# Original words:  ['running', 'jumps', 'happily', 'running', 'happily']
# Stemmed words:  ['run', 'jump', 'happili', 'run', 'happili']

# %%
from nltk.stem import WordNetLemmatizer #In NLTK (Natural Language Toolkit), stemming means reducing a word to its root/base form (called a stem) by removing prefixes or suffixes.
import nltk
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

print("rocks: ", lemmatizer.lemmatize("rocks"))
print("corpora: ", lemmatizer.lemmatize("corpora"))

print("better: ", lemmatizer.lemmatize("better", pos="a"))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# rocks:  rock
# corpora:  corpus
# better:  good

# %%
from nltk.stem import PorterStemmer

file_path = "/content/stemming_text.txt"
with open(file_path, "r") as f:
    text = f.read()

ps = PorterStemmer()

words = text.replace("\n", " ").split()
stemmed_words = [ps.stem(w) for w in words]

print("Original words: ", words)
print("Stemmed words: ", stemmed_words)
# Out:
# Original words:  ['Running', 'faster', 'than', 'usual', 'the', 'athletes', 'were', 'practicing', 'early', 'in', 'the', 'morning', 'They', 'enjoyed', 'competing', 'learning', 'studying', 'and', 'improving', 'their', 'skills', 'every', 'day', 'Some', 'were', 'hoping', 'for', 'better', 'results', 'while', 'others', 'were', 'focusing', 'on', 'training', 'smarter', 'Players', 'kept', 'moving', 'jumping', 'playing', 'and', 'preparing', 'continuously', 'despite', 'challenging', 'weather', 'conditions']
# Stemmed words:  ['run', 'faster', 'than', 'usual', 'the', 'athlet', 'were', 'practic', 'earli', 'in', 'the', 'morn', 'they', 'enjoy', 'compet', 'learn', 'studi', 'and', 'improv', 'their', 'skill', 'everi', 'day', 'some', 'were', 'hope', 'for', 'better', 'result', 'while', 'other', 'were', 'focus', 'on', 'train', 'smarter', 'player', 'kept', 'move', 'jump', 'play', 'and', 'prepar', 'continu', 'despit', 'challeng', 'weather', 'condit']
