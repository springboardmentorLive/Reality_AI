# %%
pip install pandas

# %%
pip install pillow

# %%
from PIL import Image

#Open an image
image = Image.open("flower.jpg")

#Display the image
image.show()

#Resize the image
resized_image =  image.resize((200, 200))

#Save the image
resized_image.save("resized example.jpg")

# %%
rotated_image = image.rotate(45)

rotated_image
# Out:
# <PIL.Image.Image image mode=RGB size=198x264>

# %%
cropped_image = image.crop((10, 10, 100, 100)) # left,top,right,bottom
cropped_image
# Out:
# <PIL.Image.Image image mode=RGB size=90x90>

# %%
grayscale_image = image.convert("L")#lumine
grayscale_image
# Out:
# <PIL.Image.Image image mode=L size=198x264>
