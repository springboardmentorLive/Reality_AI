# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentorLive/Reality_AI/blob/ananyarohidasshet/IS_Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import WordNetLemmatizer

import nltk

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

print("rocks:", lemmatizer.lemmatize("rocks"))

print("corpora :", lemmatizer.lemmatize("corpora"))

# a denotes adjective in "pos"

print("better:", lemmatizer.lemmatize("better", pos="a"))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# rocks: rock
# corpora : corpus
# better: good

# %%
from nltk.stem import PorterStemmer

# Create a Porter Stemmer instance

porter_stemmer = PorterStemmer()

# Example words for stemming

words = ["running", "jumps", "happily", "running", "happily"]

# Apply stemming to each word

stemmed_words = [porter_stemmer.stem(word) for word in words]

# Print the results

print("Original words:", words)

print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['running', 'jumps', 'happily', 'running', 'happily']
# Stemmed words: ['run', 'jump', 'happili', 'run', 'happili']

# %%
from nltk.stem import PorterStemmer

#Create a PorterStemmer instance

porter_stemmer = PorterStemmer()

# Read words from a text file

with open("word.txt", "r") as file:
  text = file.read()

# Split words by space or newline

words = text.split()

# Apply stemming

stemmed_words = [porter_stemmer.stem(word) for word in words]

#Print results

print("Original words:", words)

print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['Students', 'are', 'studying', 'hard', 'for', 'their', 'exams.', 'They', 'studied', 'different', 'subjects', 'and', 'studies', 'helped', 'them', 'gain', 'knowledge.', 'Running', 'runners', 'run', 'quickly', 'during', 'morning', 'runs.', 'The', 'programmer', 'programs', 'and', 'programmed', 'many', 'programs.', 'Cats', 'are', 'chasing', 'mice', 'and', 'played', 'happily.', 'Writing', 'writers', 'write', 'written', 'content', 'daily.', 'Learning', 'learners', 'learn', 'learned', 'lessons.', 'Jumping', 'jumped', 'jumps', 'are', 'forms', 'of', 'jump.', 'Organizations', 'organize', 'organized', 'organizing', 'events.', 'Reading', 'readers', 'read', 'readable', 'books', 'regularly.']
# Stemmed words: ['student', 'are', 'studi', 'hard', 'for', 'their', 'exams.', 'they', 'studi', 'differ', 'subject', 'and', 'studi', 'help', 'them', 'gain', 'knowledge.', 'run', 'runner', 'run', 'quickli', 'dure', 'morn', 'runs.', 'the', 'programm', 'program', 'and', 'program', 'mani', 'programs.', 'cat', 'are', 'chase', 'mice', 'and', 'play', 'happily.', 'write', 'writer', 'write', 'written', 'content', 'daily.', 'learn', 'learner', 'learn', 'learn', 'lessons.', 'jump', 'jump', 'jump', 'are', 'form', 'of', 'jump.', 'organ', 'organ', 'organ', 'organ', 'events.', 'read', 'reader', 'read', 'readabl', 'book', 'regularly.']

# %%
# Simple anomaly detection for credit card transactions

#Sample transactions: (amount, location)

transactions = [

(20, "local"),# grocery
(50, "local"),#gas
(1000, "local"),#online shopping
(508, "foreign"),# jewelry purchase abroad
(200, "local"),#electronics
]

#Define thresholds

MAX_NORMAL_AMOUNT = 1000 #anything above this is suspicious

ALLOWED_LOCATIONS = ["local"]

def detect_anomalies (transactions):
  anomalies = []
  for idx, (amount, location) in enumerate (transactions, start=1):
    if amount > MAX_NORMAL_AMOUNT or location not in ALLOWED_LOCATIONS:
      anomalies.append({
          "transaction_id":idx,
          "amount": amount,
          "location": location,
          "reason": "High amount" if amount> MAX_NORMAL_AMOUNT else "Unusual location"
      })
  return anomalies

#Run detection
anomalies = detect_anomalies(transactions)
#Print results
if anomalies:
  print("Suspicious transactions detected:")
  for anomaly in anomalies:
    print(f"ID {anomaly['transaction_id']}: ${anomaly['amount']} at {anomaly['location']} {anomaly['reason']}")
else:
  print("No anomalies detected.")
# Out:
# Suspicious transactions detected:
# ID 4: $508 at foreign Unusual location
