# %%
#28-11-25

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_new = df.drop_duplicates()
print("clean Dataset")
print(df_new)
# Out:
# clean Dataset
#   Department  ExperienceYears  Salary
# 0         HR                2   45500
# 1         IT                5   70000
# 2         IT                5   72000
# 3      Sales                3   50000
# 4    Finance                7   83000

# %%
data = {
    "Department": [
        "HR", "IT", "IT",
        "Sales", "Finance", "Sales", "HR"],
    "ExperienceYears": [
        2, 5, 5, 3, 7, 3, 2],
    "Salary": [
        45500, 70000, 72000,50000, 83000, 50000, 45500]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Department  ExperienceYears  Salary
# 0         HR                2   45500
# 1         IT                5   70000
# 2         IT                5   72000
# 3      Sales                3   50000
# 4    Finance                7   83000
# 5      Sales                3   50000
# 6         HR                2   45500

# %%
print(df.duplicated())

# %%
plt.figure(figsize=(6,4))
plt.bar(df_new["ExperienceYears"], df_new["Salary"], color="orange")
plt.title("Experience vs Salary")
plt.xlabel("Experience(Years)")
plt.ylabel("Salary")
plt.show()

# %%
plt.figure(figsize=(6,4))
df_new.hist(column="Salary", by="Department")
plt.title("Salary Distribution by Department")
plt.suptitle("")
plt.show()
